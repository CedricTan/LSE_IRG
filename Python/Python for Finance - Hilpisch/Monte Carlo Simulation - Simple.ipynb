# %%
# A Monte Carlo simulation is used to model the probability of different outcomes in a process that cannot easily be
# predicted due to the intervention of random variables. It is a technique used to understand the impact of risk
# and uncertainty in prediction and forecasting models

# Game - if I roll 1-51 I lose, if I roll 52-100 I win
# Dice has numbers 1-100
# Expected profit from a $1 bet is 1*(49/100)-1*(52/100) = $-0.02 i.e. negative two cents or negative 2%

# Libraries
import random
import matplotlib.pyplot as plt

# %%
# Function for dice roll
def rolldice():
    dice = random.randint(1,100)
    
    if dice <=51:
        return False
    elif dice > 51 & dice <=100:
        return True

# %%
# Function for playing the game where we define:
# 1. total_funds
# 2. wager_amount
# 3. total_plays

def play (total_funds, wager_amount, total_plays):
    play_num = []
    funds = []
    
    play = 1
    
    while play <= total_plays:
        if rolldice():
            total_funds = total_funds + wager_amount
            play_num.append(play)
            funds.append(total_funds)
        else:
            total_funds = total_funds - wager_amount
            play_num.append(play)
            funds.append(total_funds)
        
        play = play + 1
    
    plt.plot(play_num, funds)
    final_funds.append(funds[-1])
    return(final_funds)

# %%
# Having defined our function, we can now run iterations

# Initialise the scenario as x = 1
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,5)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9968.0

# %%
# More iterations
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,10)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9978.0

# %%
# Even more
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,50)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9982.0

# %%
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,100)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9750.0

# %%
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,500)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $8750.0

# %%
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,1000)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $8022.0

# %%
x = 1
final_funds = []

while x <= 100:
    ending_fund = play(10000,100,10000)
    x = x + 1

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print('The player starts the game with $10,000 and ends with $' + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $-8666.0
